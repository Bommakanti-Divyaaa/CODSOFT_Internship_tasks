# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read csv file
df = pd.read_csv("../data/raw/Titanic_dataset.csv")

# %%
# show first 5 passangers
df.head()

# %%
# shape
df.shape

# %%
df.columns

# %% [markdown]
# Cleaning columns - PassengerID - only id.no --> not needed<br>
# Survived --> def. needed<br>
# Pclass -> social hierrarchy -->needed<br>
# name --> not needed<br>
# sex -> needed(evacuation followed women and children first!)<br>
# age --> needed<br>
# sibSp -->familiy support and group travelling hint<br>
# Patch --> parents/children<br>
# tktnum --> Not needed. Why? because it looks like this<br>
#                             A/5 21171<br>
# Fare --> higer fare -> rich -> better cabin place -> higher evacuation chance<br>
# cabin --> too many missing valuse<br>
# Embarked --> Very diverse<br>

# %%
# checking data types to identify null values
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# Drop Cabin(687 missing values)
# embarked could be filled
# age is needed. So find a way to fill(imputation)

# %%
# survival count
df['Survived'].value_counts()

# %%
# Percentage
df['Survived'].value_counts(normalize = True) * 100

# %%
df.groupby('Sex')['Survived'].mean() * 100

# %%
df.groupby('Pclass')['Survived'].mean() * 100

# %%
sns.countplot(x="Survived", data=df)
plt.title("Survival Count")
plt.show()
